# %% [markdown]
# # Explorando los datos de los estudiantes

# %% [markdown]
# Imagine que trabaja para un distrito escolar y ha recopilado algunos datos sobre los estudiantes locales y sus padres. Se te ha encomendado responder algunas preguntas importantes:
#
# *   ¿Cómo se están desempeñando los estudiantes en sus clases de matemáticas?
# *   ¿Qué hacen los padres de los estudiantes en el trabajo?
# *   ¿Con qué frecuencia los estudiantes faltan a la escuela?
#
# En este proyecto, explorará y resumirá algunos datos de los estudiantes para responder estas preguntas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Importar datos
students = pd.read_csv('/content/drive/MyDrive/Analitica/2. Resumen de Datos/Proyecto-WS2/students.csv')

# %% [markdown]
# ##Exploración inicial

# %% [markdown]
# 1. El marco de datos proporcionado (guardado como `students`) incluye las siguientes variables/características:
#
#
# *   `address`: la ubicación de la casa del estudiante (`'U'` para urbano y `'R'` para rural)
# *   `absences`: el número de veces que el estudiante estuvo ausente durante el año escolar
# *   `Mjob`: la industria del trabajo de la madre del estudiante
# *   `Fjob`: la industria del trabajo del padre del estudiante
# *   `math_grade`: la calificación final del estudiante en matemáticas, que va de 0 a 20
#
# Usa el método pandas `.head()` para inspeccionar las primeras filas de datos.

# %%
students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences math_grade  G2  G3
# 0      4        3      4     1     1      3        6          5   6   6
# 1      5        3      3     1     1      3        4          5   5   6
# 2      4        3      2     2     3      3       10          7   8  10
# 3      3        2      2     1     1      5        2         15  14  15
# 4      4        3      2     1     2      5        4          6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# 2. Use el método pandas `.describe()` para imprimir estadísticas resumidas para las características en el conjunto de datos. Inspeccione la salida. ¿Viven más estudiantes en localidades urbanas o rurales?

# %%
students.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     395     395     395  395.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     307     281     354         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  ...      famrel    freetime       goout  \
# count   395.000000    395    395  ...  395.000000  395.000000  395.000000
# ...

# %% [markdown]
# ##Resumir la calificación típica de un estudiante

# %% [markdown]
# 3. Empecemos tratando de resumir la columna `math_grade`. Calcule e imprima el valor medio de `math_grade`.

# %%
students.math_grade.mean()
# Out:
# 10.90886075949367

# %% [markdown]
# 4. A continuación, calcule e imprima el valor medio de `math_grade`. Compara este valor con la media. ¿Es más pequeño? ¿Más grande?

# %%
students.math_grade.median()
# Out:
# 11.0

# %% [markdown]
# 5. Finalmente, calcule e imprima la moda de la columna `math_grade`. ¿Cuál es la calificación más común obtenida por los estudiantes en este conjunto de datos? ¿Qué tan diferente es este número de la media y la mediana?

# %%
students.math_grade.mode()[0]
# Out:
# 10

# %% [markdown]
# ##Resumir la distribución de las calificaciones de los estudiantes

# %% [markdown]
# 6. A continuación, resumamos la distribución de las calificaciones de los estudiantes. Calcule e imprima el rango de la columna `math_grade`.

# %%
students.math_grade.max() - students.math_grade.min()
# Out:
# 16

# %% [markdown]
# 7. Calcule e imprima la desviación estándar de la columna `math_grade`. Alrededor de dos tercios de los valores se encuentran dentro de una desviación estándar de la media. ¿Qué te dice este número acerca de cuánto varían las calificaciones en matemáticas?

# %%
students.math_grade.std()
# Out:
# 3.3191946715076686

# %% [markdown]
# 8. Finalmente, calcule la desviación absoluta media de la columna `math_grade`. Esta es la diferencia media entre la puntuación de cada estudiante y la puntuación media.

# %%
students.math_grade.mad()
# Out:
# 2.75144367889761

# %% [markdown]
# ##Visualice la distribución de las calificaciones de los estudiantes

# %% [markdown]
# 9. Ahora que hemos resumido las calificaciones de los estudiantes usando estadísticas de tendencia central y dispersión, visualicemos la distribución usando un histograma. Use la función seaborn `histplot()` para crear un histograma de `math_grade`.

# %%
sns.histplot(x = 'math_grade', data = students)

# %% [markdown]
# 10. Otra forma de visualizar la distribución de una variable cuantitativa es mediante un diagrama de caja. Use la función seaborn `boxplot()` para crear un diagrama de caja de `math_grade`.
# Asegúrese de agregar este código después de la primera llamada a `plt.clf()` desde el gráfico anterior y antes de la segunda llamada a `plt.show()`.

# %%
sns.boxplot(x = 'math_grade', data = students)

# %% [markdown]
# ##Resumir el trabajo de las madres

# %% [markdown]
# 11. La columna `Mjob` en el conjunto de datos contiene información sobre lo que hacen las madres de los estudiantes como profesión. Resuma la columna `Mjob` imprimiendo el número de estudiantes que tienen madres con cada tipo de trabajo.
# ¿Qué valor de `Mjob` es el más común?

# %%
students.Mjob.value_counts()
# Out:
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64

# %% [markdown]
# 12. Ahora, calcule e imprima la proporción de estudiantes que tienen madres con cada tipo de trabajo. ¿Qué proporción de estudiantes tienen madres que trabajan en salud?

# %%
students.Mjob.value_counts(normalize = True)
# Out:
# other       0.356962
# services    0.260759
# at_home     0.149367
# teacher     0.146835
# health      0.086076
# Name: Mjob, dtype: float64

# %% [markdown]
# ##Visualize the distribution of mothers' jobs

# %% [markdown]
# 13. Ahora que hemos usado estadísticas de resumen para comprender las frecuencias relativas de los trabajos de diferentes madres, visualicemos la misma información con un gráfico de barras. Utilice la función seaborn `countplot()` para crear un gráfico de barras de la variable `Mjob`.

# %%
sns.countplot(x = 'Mjob', data = students)

# %% [markdown]
# 14. También podemos visualizar la misma información utilizando un gráfico circular. Cree un gráfico circular de la columna Mjob.

# %%
students.Mjob.value_counts().plot.pie()

# %% [markdown]
# ##Exploración adicional

# %% [markdown]
# Ha comenzado a explorar un conjunto de datos mediante el cálculo de estadísticas de resumen y la creación de algunas visualizaciones de datos básicas. Todavía hay algunas columnas más en este conjunto de datos que no hemos analizado detenidamente:
#
#
# *   `address`: la ubicación de la casa del estudiante (`'U'` para urbano y `'R'` para rural)
# *   `absences`: el número de veces que el estudiante estuvo ausente durante el año escolar
# *    `Fjob`: la industria del trabajo del padre del estudiante
#
# Ahora que lo hemos guiado a través de una exploración de `math_grade` y `Mjob` con más detalle, tómese un tiempo para explorar el resto de las columnas en el conjunto de datos ¿Qué tipos de estadísticas y visualizaciones de resumen puede usar para resumir estas columnas?
